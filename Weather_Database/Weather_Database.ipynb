# %%
import numpy as np 
from citipy import citipy
import requests
import pandas as pd 
import json
import numpy as np
import time
from datetime import datetime

from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)


lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(23.771249331413472, 130.53151653593335), (-20.419252453800482, -169.57355913765338), (86.67120571716495, 78.48958122744796), (24.56890602789865, -57.29296371710308), (-8.947189353463529, -25.45760455548725), (-51.71483659969472, 98.0299953960697), (-35.54974150527028, -136.09452419500346), (-39.78143628196845, 15.341710766709184), (-62.08390467847408, -136.510197148043), (-4.933768877577165, 19.82116465895959), (65.78051073525498, -93.8323956203438), (-51.453319972464634, 168.24760862624822), (-55.73030190343396, 21.003611823827868), (-79.19392950298287, -41.77250343820535), (54.80352871171519, 25.408281814335282), (80.84606860336274, -0.8857028767804991), (71.51769793669607, 177.18252840124183), (-63.868678535148035, 177.48443023641158), (-55.24220508545821, -101.03378997576802), (-78.34929446541715, -8.303266400579759), (24.164634431520582, 39.706940482543104), (-83.25910323690618, 92.33236311874418), (17.800200964832854, 120.64851651461697), (-35.506692725563404, -150.82601574610823), (-58.417258545228854, -159.246482376656), (29.354232698732318, -29.907432042132825), (-27.04303412073167, 24.03547897952498), (-60.593284312066764, 162.42146578689102), (78.9814432695461, 67.23259925145015), (67.01881346182387, 143.59243668632377), (-66.10828980767386, -83.21308714217426), (-40.653655344111556, 96.24645121696312), (-12.061030287298806, 127.9010662669562), (-7.553547609903802, 103.21558596237236), (-7.202713644106211, -169.56363220417143), (-10.176133660894308, -114.6062363230664), (69.3252061801281, 15.518593503791607), (6.135070192529767, -99.82817435890271), (-6.966557384645654, -142.3449599592618), (16.039788411816374, -167.84090580036352), (-29.469938406165305, 29.951085533799215), (10.79998912887055, -9.418562587503601), (1.035286863696669, 149.77392360724605), (41.67626614449935, -81.43603946864748), (54.306319857489825, -107.28949370522645), (-73.89840390240218, -64.4004190026654), (17.12590570278806, -117.66494623569133), (-58.65806095066529, 16.25109005291708), (64.42057673718543, 1.085230649889212), (35.47042006179478, 1.452439218785372), (42.37218850996419, -23.60803167929498), (-26.846659343817322, -10.811819859342108), (26.48989818337371, 175.3555565879118), (52.27797582461113, 106.61120172837911), (-34.967839151463856, -9.555275391926585), (36.49697714152478, -112.19724472758081), (-41.48309080660619, -54.24071598429096), (-21.374210392169317, 122.64398346870985), (59.84609009575354, 37.06379851115565), (16.27565474085374, 26.10924890902666), (32.94813703502339, 4.37427679020476), (87.95373096815013, -113.95754986637354), (-4.849004492272428, 79.86554992718851), (40.934539927960316, -171.2412127910175), (-34.402007676230966, -108.98950185554578), (19.54248501574078, -106.25759064788116), (55.24454868846166, 139.33219246318413), (-67.76041482471469, 47.3335781771965), (-81.00025542227684, 161.06248675018992), (-58.726727086057856, 22.179121771387457), (46.8806737364078, -45.57497496491749), (-16.178622536288472, -70.2063836723681), (37.55758699224437, 122.31736264436154), (-33.84841673684749, -13.842560232957965), (16.078046659408272, 77.84612124930197), (-40.36875929216353, -140.8657492267248), (-42.30138699028734, 50.63831663867356), (-7.427477898672649, -120.08836106440322), (-81.66538516102736, 149.58145484672445), (-20.979996042808267, 51.73776311787742), (-58.23055931568151, -101.72865065614553), (64.1621248680604, -6.491219257063449), (80.17147855219176, 78.50657406799104), (-85.48275293743549, -36.82602286057957), (-86.44919114202409, -146.6793263162239), (-87.55822892472628, 1.7080358503500577), (56.703684639512744, -78.45296413686967), (-38.77387839408358, -80.0598648272719), (-9.379717917087433, 52.04393596125112), (-55.833938088248445, 107.2920522569762), (31.587741077931838, 121.13926194751281), (-83.25955849828992, 170.71068910881957), (-6.21726139848802, -62.54447395638849), (-3.611584008085913, -74.73999977821283), (-20.53875913984092, -89.11616932898608), (53.07228229812037, -124.66470270157245) ...

# %%
# Get the nearest city using the citipy module

cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Perform an API call with the OpenWeatherMap.

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=257b844c0cc5720c680b7f610db0f588

# %%
# Retrieve the following information from the API call:
# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")


    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
        # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        description = city_weather['weather'][0]['description']
            
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nishihara
# Processing Record 2 of Set 1 | alofi
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | codrington
# Processing Record 5 of Set 1 | olinda
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | mangai
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | nemencine
# Processing Record 15 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 1 | leningradskiy
# Processing Record 17 of Set 1 | kaitangata
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | umm lajj
# Processing Record 20 of Set 1 | albany
# Processing Record 21 of Set 1 | la paz
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ribeira grande
# Processing Record 24 of Set 1 | vryburg
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | port keats
# Processing Record 29 of Set 1 | pringsewu
# Processing Record 30 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 1 | myre
# Processing Record 32 of Set 1 | puerto escondido
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | mpophomeni
# Processing Record 36 of Set 1 | kankan
# Processing Record 37 of Set 1 | kavieng
# Processing Record 38 of Set 1 | eastlake
# Processing Record 39 of Set 1 | meadow lake
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | brae
# Processing Record 42 of Set 1 | sidi ali
# Processing Record 43 of Set 1 | rabo de peixe
# Processing Record 44 of Set 1 | jamestown
# Processing Record 45 of Set 1 | butaritari
# Processing Record 46 of Set 1 | kabansk
# Processing Record 47 of Set 1 | hurricane
# Processing Record 48 of Set 1 | mar del plata
# Processing Record 49 of Set 1 | broome
# Processing Record 50 of Set 1 | kaduy
# Processing Record 1 of Set 2 | kutum
# Processing Record 2 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 2 | yellowknife
# Processing Record 4 of Set 2 | hithadhoo
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | tomatlan
# Processing Record 7 of Set 2 | mnogovershinnyy
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | torbay
# Processing Record 10 of Set 2 | puno
# Processing Record 11 of Set 2 | weihai
# Processing Record 12 of Set 2 | gadwal
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | mahanoro
# Processing Record 16 of Set 2 | klaksvik
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | ambilobe
# Processing Record 21 of Set 2 | yushan
# Processing Record 22 of Set 2 | tapaua
# City not found. Skipping...
# Processing Record 23 of Set 2 | iquitos
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | vanderhoof
# Processing Record 26 of Set 2 | sangar
# Processing Record 27 of Set 2 | sobolevo
# Processing Record 28 of Set 2 | pagudpud
# Processing Record 29 of Set 2 | severo-kurilsk
# Processing Record 30 of Set 2 | remontnoye
# Processing Record 31 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 32 of Set 2 | caravelas
# Processing Record 33 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 2 | ponta do sol
# Processing Record 35 of Set 2 | manokwari
# Processing Record 36 of Set 2 | den helder
# Processing Record 37 of Set 2 | oktyabrskoye
# Processing Record 38 of Set 2 | scottsboro
# Processing Record 39 of Set 2 | viet tri
# Processing Record 40 of Set 2 | boa vista
# Processing Record 41 of Set 2 | saanen
# Processing Record 42 of Set 2 | bougouni
# Processing Record 43 of Set 2 | bengkulu
# Processing Record 44 of Set 2 | clyde river
# Processing Record 45 of Set 2 | olga
# Processing Record 46 of Set 2 | ledyard
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | tuktoyaktuk
# Processing Record 49 of Set 2 | geraldton
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | russell
# Processing Record 2 of Set 3 | zhangye
# Processing Record 3 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 4 of Set 3 | quelimane
# Processing Record 5 of Set 3 | andenes
# Processing Record 6 of Set 3 | belmonte
# Processing Record 7 of Set 3 | cherskiy
# Processing Record 8 of Set 3 | miandrivazo
# Processing Record 9 of Set 3 | pitimbu
# Processing Record 10 of Set 3 | minab
# Processing Record 11 of Set 3 | lorengau
# Processing Record 12 of Set 3 | vastervik
# City not found. Skipping...
# Processing Record 13 of Set 3 | upernavik
# Processing Record 14 of Set 3 | falun
# Processing Record 15 of Set 3 | tonj
# Processing Record 16 of Set 3 | iraucuba
# Processing Record 17 of Set 3 | yar-sale
# Processing Record 18 of Set 3 | saint george
# Processing Record 19 of Set 3 | carnarvon
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | chokurdakh
# Processing Record 22 of Set 3 | radom
# Processing Record 23 of Set 3 | qaanaaq
# Processing Record 24 of Set 3 | stabat
# Processing Record 25 of Set 3 | mo i rana
# Processing Record 26 of Set 3 | ilulissat
# Processing Record 27 of Set 3 | mahebourg
# Processing Record 28 of Set 3 | sosnovo-ozerskoye
# Processing Record 29 of Set 3 | muli
# Processing Record 30 of Set 3 | ostersund
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | raudeberg
# Processing Record 34 of Set 3 | new norfolk
# Processing Record 35 of Set 3 | sao jose da coroa grande
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | floro
# Processing Record 39 of Set 3 | puerto del rosario
# Processing Record 40 of Set 3 | rajshahi
# Processing Record 41 of Set 3 | tobermory
# Processing Record 42 of Set 3 | nuuk
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | lompoc
# Processing Record 46 of Set 3 | play cu
# City not found. Skipping...
# Processing Record 47 of Set 3 | lagoa
# Processing Record 48 of Set 3 | buala
# Processing Record 49 of Set 3 | magistralnyy
# Processing Record 50 of Set 3 | nikolskoye
# Processing Record 1 of Set 4 | miri
# Processing Record 2 of Set 4 | salalah
# Processing Record 3 of Set 4 | kyren
# Processing Record 4 of Set 4 | teguise
# Processing Record 5 of Set 4 | soroti
# Processing Record 6 of Set 4 | somotillo
# Processing Record 7 of Set 4 | khatanga
# Processing Record 8 of Set 4 | andros town
# Processing Record 9 of Set 4 | seymchan
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | yaransk
# Processing Record 12 of Set 4 | hualmay
# Processing Record 13 of Set 4 | sitka
# Processing Record 14 of Set 4 | hilo
# Processing Record 15 of Set 4 | taltal
# Processing Record 16 of Set 4 | bodmin
# Processing Record 17 of Set 4 | coquimbo
# Processing Record 18 of Set 4 | belaya gora
# Processing Record 19 of Set 4 | cidreira
# Processing Record 20 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 21 of Set 4 | sulangan
# Processing Record 22 of Set 4 | namatanai
# Processing Record 23 of Set 4 | velikie luki
# City not found. Skipping...
# Processing Record 24 of Set 4 | mapiri
# Processing Record 25 of Set 4 | hirara
# Processing Record 26 of Set 4 | praia
# Processing Record 27 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | haines junction
# Processing Record 30 of Set 4 | dezful
# Processing Record 31 of Set 4 | comodoro rivadavia
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | hofn
# Processing Record 35 of Set 4 | ivanava
# Processing Record 36 of Set 4 | praia da vitoria
# Processing Record 37 of Set 4 | saint-philippe
# Processing Record 38 of Set 4 | soyaux
# Processing Record 39 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 4 | beringovskiy
# Processing Record 41 of Set 4 | valdivia
# Processing Record 42 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 43 of Set 4 | kotelnich
# Processing Record 44 of Set 4 | neftcala
# Processing Record 45 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 4 | uruguaiana
# Processing Record 47 of Set 4 | limbang
# Processing Record 48 of Set 4 | santa fe
# Processing Record 49 of Set 4 | southbridge
# Processing Record 50 of Set 4 | taoudenni
# Processing Record 1 of Set 5 | el balyana
# City not found. Skipping...
# Processing Record 2 of Set 5 | madimba
# Processing Record 3 of Set 5 | conde
# Processing Record 4 of Set 5 | mehran
# Processing Record 5 of Set 5 | itapicuru
# Processing Record 6 of Set 5 | omboue
# Processing Record 7 of Set 5 | georgetown
# Processing Record 8 of Set 5 | esperance
# Processing Record 9 of Set 5 | college
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | kudahuvadhoo
# Processing Record 14 of Set 5 | kilembe
# Processing Record 15 of Set 5 | ous
# Processing Record 16 of Set 5 | kendari
# Processing Record 17 of Set 5 | bremerton
# Processing Record 18 of Set 5 | saldanha
# Processing Record 19 of Set 5 | kinshasa
# Processing Record 20 of Set 5 | traralgon
# Processing Record 21 of Set 5 | sutton coldfield
# Processing Record 22 of Set 5 | camacupa
# Processing Record 23 of Set 5 | svetlyy
# Processing Record 24 of Set 5 | rio grande
# Processing Record 25 of Set 5 | altay
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | xicotencatl
# Processing Record 28 of Set 5 | quatre cocos
# Processing Record 29 of Set 5 | doka
# Processing Record 30 of Set 5 | isangel
# Processing Record 31 of Set 5 | severo-yeniseyskiy
# Processing Record 32 of Set 5 | saint-francois
# Processing Record 33 of Set 5 | vasto
# Processing Record 34 of Set 5 | coihaique
# Processing Record 35 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 5 | havre-saint-pierre
# Processing Record 38 of Set 5 | acarau
# Processing Record 39 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 5 | san quintin
# Processing Record 41 of Set 5 | westport
# Processing Record 42 of Set 5 | benjamin constant
# Processing Record 43 of Set 5 | ancud
# Processing Record 44 of Set 5 | puerto ayora
# Processing Record 45 of Set 5 | mount gambier
# Processing Record 46 of Set 5 | shelburne
# Processing Record 47 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 5 | sur
# Processing Record 49 of Set 5 | gaziantep
# Processing Record 50 of Set 5 | north bend
# Processing Record 1 of Set 6 | kuruman
# Processing Record 2 of Set 6 | iralaya
# Processing Record 3 of Set 6 | tuatapere
# Processing Record 4 of Set 6 | oster
# Processing Record 5 of Set 6 | airai
# Processing Record 6 of Set 6 | kluczbork
# Processing Record 7 of Set 6 | lasa
# Processing Record 8 of Set 6 | arti
# Processing Record 9 of Set 6 | victoria
# Processing Record 10 of Set 6 | nyurba
# Processing Record 11 of Set 6 | nizhniy bestyakh
# Processing Record 12 of Set 6 | abu samrah
# Processing Record 13 of Set 6 | kruisfontein
# Processing Record 14 of Set 6 | chapais
# Processing Record 15 of Set 6 | north platte
# Processing Record 16 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 17 of Set 6 | roma
# Processing Record 18 of Set 6 | emba
# Processing Record 19 of Set 6 | sartana
# Processing Record 20 of Set 6 | hambantota
# Processing Record 21 of Set 6 | plouzane
# Processing Record 22 of Set 6 | duz
# City not found. Skipping...
# Processing Record 23 of Set 6 | colon
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | maarianhamina
# Processing Record 26 of Set 6 | makung
# City not found. Skipping...
# Processing Record 27 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 6 | lac du bonnet
# Processing Record 29 of Set 6 | oistins
# Processing Record 30 of Set 6 | peterhead
# Processing Record 31 of Set 6 | yantal
# Processing Record 32 of Set 6 | divnogorsk
# Processing Record 33 of Set 6 | cananeia
# Processing Record 34 of Set 6 | mondovi
# Processing Record 35 of Set 6 | jalu
# Processing Record 36 of Set 6 | avarua
# Processing Record 37 of Set 6 | rostusa
# Processing Record 38 of Set 6 | shingu
# Processing Record 39 of Set 6 | necochea
# Processing Record 40 of Set 6 | atasu
# Processing Record 41 of Set 6 | souillac
# Processing Record 42 of Set 6 | kaka
# Processing Record 43 of Set 6 | pereleshino
# Processing Record 44 of Set 6 | amahai
# Processing Record 45 of Set 6 | vila franca do campo
# Processing Record 46 of Set 6 | voskresenskoye
# Processing Record 47 of Set 6 | harper
# Processing Record 48 of Set 6 | port hardy
# Processing Record 49 of Set 6 | campoverde
# Processing Record 50 of Set 6 | tessalit
# Processing Record 1 of Set 7 | yulara
# Processing Record 2 of Set 7 | ciudad bolivar
# Processing Record 3 of Set 7 | san gavino monreale
# Processing Record 4 of Set 7 | morondava
# Processing Record 5 of Set 7 | burnsville
# Processing Record 6 of Set 7 | hasaki
# Processing Record 7 of Set 7 | pierre
# Processing Record 8 of Set 7 | tyumentsevo
# Processing Record 9 of Set 7 | bossembele
# City not found. Skipping...
# Processing Record 10 of Set 7 | marsa matruh
# Processing Record 11 of Set 7 | jaffrey
# Processing Record 12 of Set 7 | tilichiki
# Processing Record 13 of Set 7 | san juan
# Processing Record 14 of Set 7 | la peca
# Processing Record 15 of Set 7 | abu kamal
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 18 of Set 7 | korla
# Processing Record 19 of Set 7 | nola
# Processing Record 20 of Set 7 | tasiilaq
# Processing Record 21 of Set 7 | juneau
# Processing Record 22 of Set 7 | barcelona
# Processing Record 23 of Set 7 | sola
# Processing Record 24 of Set 7 | ovalle
# Processing Record 25 of Set 7 | fenoarivo
# Processing Record 26 of Set 7 | passo de camaragibe
# Processing Record 27 of Set 7 | vanavara
# Processing Record 28 of Set 7 | tigil
# Processing Record 29 of Set 7 | kaohsiung
# Processing Record 30 of Set 7 | katsuura
# Processing Record 31 of Set 7 | fare
# Processing Record 32 of Set 7 | sao borja
# Processing Record 33 of Set 7 | naze
# Processing Record 34 of Set 7 | guerrero negro
# Processing Record 35 of Set 7 | flinders
# Processing Record 36 of Set 7 | manggar
# Processing Record 37 of Set 7 | saskylakh
# Processing Record 38 of Set 7 | arraial do cabo
# Processing Record 39 of Set 7 | nador
# Processing Record 40 of Set 7 | fallon
# Processing Record 41 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 42 of Set 7 | zhigansk
# Processing Record 43 of Set 7 | atlautla
# Processing Record 44 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 45 of Set 7 | karpogory
# Processing Record 46 of Set 7 | de-kastri
# Processing Record 47 of Set 7 | dawei
# Processing Record 48 of Set 7 | cacu
# Processing Record 49 of Set 7 | yumen
# Processing Record 50 of Set 7 | atbasar
# Processing Record 1 of Set 8 | megion
# Processing Record 2 of Set 8 | pouembout
# Processing Record 3 of Set 8 | upington
# Processing Record 4 of Set 8 | jiuquan
# Processing Record 5 of Set 8 | san cristobal
# Processing Record 6 of Set 8 | la rioja
# Processing Record 7 of Set 8 | sindgi
# Processing Record 8 of Set 8 | rosignano marittimo
# Processing Record 9 of Set 8 | pontes e lacerda
# Processing Record 10 of Set 8 | bathsheba
# Processing Record 11 of Set 8 | changchun
# Processing Record 12 of Set 8 | sinnamary
# Processing Record 13 of Set 8 | shama
# Processing Record 14 of Set 8 | kinkala
# Processing Record 15 of Set 8 | skjervoy
# Processing Record 16 of Set 8 | huarmey
# Processing Record 17 of Set 8 | mabaruma
# Processing Record 18 of Set 8 | winnemucca
# Processing Record 19 of Set 8 | kahului
# Processing Record 20 of Set 8 | mabiton
# Processing Record 21 of Set 8 | great yarmouth
# Processing Record 22 of Set 8 | khani
# Processing Record 23 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 8 | kasongo-lunda
# Processing Record 25 of Set 8 | cockburn town
# Processing Record 26 of Set 8 | pangnirtung
# Processing Record 27 of Set 8 | wanning
# Processing Record 28 of Set 8 | bermeo
# Processing Record 29 of Set 8 | yinchuan
# Processing Record 30 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 8 | vilhena
# Processing Record 33 of Set 8 | hyeres
# Processing Record 34 of Set 8 | rasht
# Processing Record 35 of Set 8 | san andres
# Processing Record 36 of Set 8 | dongkan
# Processing Record 37 of Set 8 | waipawa
# Processing Record 38 of Set 8 | hami
# Processing Record 39 of Set 8 | husavik
# Processing Record 40 of Set 8 | laguna
# Processing Record 41 of Set 8 | beloha
# Processing Record 42 of Set 8 | santa rosa
# Processing Record 43 of Set 8 | havelock
# Processing Record 44 of Set 8 | hohhot
# Processing Record 45 of Set 8 | kuntaur
# Processing Record 46 of Set 8 | chippewa falls
# Processing Record 47 of Set 8 | hobyo
# Processing Record 48 of Set 8 | port angeles
# Processing Record 49 of Set 8 | ninh binh
# Processing Record 50 of Set 8 | pemberton
# Processing Record 1 of Set 9 | gejiu
# Processing Record 2 of Set 9 | fortuna
# Processing Record 3 of Set 9 | paucartambo
# City not found. Skipping...
# Processing Record 4 of Set 9 | uusikaupunki
# Processing Record 5 of Set 9 | fukue
# Processing Record 6 of Set 9 | cadillac
# Processing Record 7 of Set 9 | shubarkuduk
# Processing Record 8 of Set 9 | oga
# Processing Record 9 of Set 9 | nizhniy kuranakh
# Processing Record 10 of Set 9 | grindavik
# Processing Record 11 of Set 9 | carutapera
# Processing Record 12 of Set 9 | boulder city
# Processing Record 13 of Set 9 | san-pedro
# Processing Record 14 of Set 9 | bara
# Processing Record 15 of Set 9 | nome
# Processing Record 16 of Set 9 | puerto madero
# Processing Record 17 of Set 9 | redmond
# Processing Record 18 of Set 9 | lumsden
# Processing Record 19 of Set 9 | banjarmasin
# Processing Record 20 of Set 9 | ketchikan
# Processing Record 21 of Set 9 | aklavik
# Processing Record 22 of Set 9 | khonsa
# Processing Record 23 of Set 9 | peace river
# Processing Record 24 of Set 9 | tlalcilalcalpan
# City not found. Skipping...
# Processing Record 25 of Set 9 | nhulunbuy
# Processing Record 26 of Set 9 | nemuro
# Processing Record 27 of Set 9 | solihull
# Processing Record 28 of Set 9 | hare bay
# Processing Record 29 of Set 9 | kokstad
# Processing Record 30 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 31 of Set 9 | saint anthony
# Processing Record 32 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 9 | powell river
# Processing Record 34 of Set 9 | xining
# Processing Record 35 of Set 9 | paita
# Processing Record 36 of Set 9 | veraval
# Processing Record 37 of Set 9 | seabra
# Processing Record 38 of Set 9 | hamilton
# Processing Record 39 of Set 9 | chicama
# Processing Record 40 of Set 9 | serenje
# Processing Record 41 of Set 9 | inirida
# Processing Record 42 of Set 9 | barrow
# Processing Record 43 of Set 9 | sorland
# Processing Record 44 of Set 9 | pemangkat
# Processing Record 45 of Set 9 | walvis bay
# Processing Record 46 of Set 9 | fairbanks
# Processing Record 47 of Set 9 | chara
# Processing Record 48 of Set 9 | aguimes
# Processing Record 49 of Set 9 | iskateley
# Processing Record 50 of Set 9 | awbari
# Processing Record 1 of Set 10 | kandrian
# Processing Record 2 of Set 10 | margate
# Processing Record 3 of Set 10 | northam
# Processing Record 4 of Set 10 | mahajanga
# Processing Record 5 of Set 10 | chuy
# Processing Record 6 of Set 10 | lavrentiya
# Processing Record 7 of Set 10 | torit
# Processing Record 8 of Set 10 | biloela
# Processing Record 9 of Set 10 | moncton
# Processing Record 10 of Set 10 | socota
# Processing Record 11 of Set 10 | miranda
# Processing Record 12 of Set 10 | tautira
# Processing Record 13 of Set 10 | goure
# Processing Record 14 of Set 10 | moerai
# Processing Record 15 of Set 10 | karasjok
# Processing Record 16 of Set 10 | male
# Processing Record 17 of Set 10 | ludwigslust
# Processing Record 18 of Set 10 | tazovskiy
# Processing Record 19 of Set 10 | monteagudo
# Processing Record 20 of Set 10 | sochi
# Processing Record 21 of Set 10 | rafai
# Processing Record 22 of Set 10 | jardim
# Processing Record 23 of Set 10 | luga
# Processing Record 24 of Set 10 | vuktyl
# Processing Record 25 of Set 10 | skagastrond
# City not found. Skipping...
# Processing Record 26 of Set 10 | camacha
# Processing Record 27 of Set 10 | marfino
# Processing Record 28 of Set 10 | karratha
# Processing Record 29 of Set 10 | san patricio
# Processing Record 30 of Set 10 | kieta
# Processing Record 31 of Set 10 | jeremie
# Processing Record 32 of Set 10 | tibati
# Processing Record 33 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 34 of Set 10 | polunochnoye
# Processing Record 35 of Set 10 | chiang kham
# Processing Record 36 of Set 10 | luderitz
# Processing Record 37 of Set 10 | jatibonico
# Processing Record 38 of Set 10 | chitral
# Processing Record 39 of Set 10 | lazarev
# Processing Record 40 of Set 10 | pocatello
# Processing Record 41 of Set 10 | coruripe
# Processing Record 42 of Set 10 | ardesen
# Processing Record 43 of Set 10 | itarema
# Processing Record 44 of Set 10 | khandagayty
# Processing Record 45 of Set 10 | catacocha
# Processing Record 46 of Set 10 | rio gallegos
# Processing Record 47 of Set 10 | bilibino
# Processing Record 48 of Set 10 | zeya
# Processing Record 49 of Set 10 | nanortalik
# Processing Record 50 of Set 10 | sozimskiy
# Processing Record 1 of Set 11 | nizhniy tsasuchey
# Processing Record 2 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 3 of Set 11 | labuhan
# Processing Record 4 of Set 11 | norman wells
# Processing Record 5 of Set 11 | pemba
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | honningsvag
# Processing Record 8 of Set 11 | ellensburg
# Processing Record 9 of Set 11 | rio verde de mato grosso
# Processing Record 10 of Set 11 | guilin
# Processing Record 11 of Set 11 | tinyahuarco
# Processing Record 12 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 11 | giron
# Processing Record 14 of Set 11 | matagami
# Processing Record 15 of Set 11 | faanui
# Processing Record 16 of Set 11 | srednekolymsk
# Processing Record 17 of Set 11 | shenzhen
# Processing Record 18 of Set 11 | aberlour
# City not found. Skipping...
# Processing Record 19 of Set 11 | avera
# Processing Record 20 of Set 11 | aranos
# Processing Record 21 of Set 11 | biak
# Processing Record 22 of Set 11 | surt
# Processing Record 23 of Set 11 | parintins
# Processing Record 24 of Set 11 | biggar
# Processing Record 25 of Set 11 | cody
# Processing Record 26 of Set 11 | kawalu
# Processing Record 27 of Set 11 | itoman
# Processing Record 28 of Set 11 | thornhill
# Processing Record 29 of Set 11 | whyalla
# Processing Record 30 of Set 11 | catio
# Processing Record 31 of Set 11 | nakhon phanom
# Processing Record 32 of Set 11 | fort nelson
# Processing Record 33 of Set 11 | richards bay
# Processing Record 34 of Set 11 | angoche
# Processing Record 35 of Set 11 | berlevag
# Processing Record 36 of Set 11 | rawson
# Processing Record 37 of Set 11 | gao
# Processing Record 38 of Set 11 | menziken
# Processing Record 39 of Set 11 | rensvik
# Processing Record 40 of Set 11 | porcsalma
# Processing Record 41 of Set 11 | ahipara
# Processing Record 42 of Set 11 | lar
# Processing Record 43 of Set 11 | hokitika
# Processing Record 44 of Set 11 | siquijor
# Processing Record 45 of Set 11 | chhukha
# City not found. Skipping...
# Processing Record 46 of Set 11 | san jose
# Processing Record 47 of Set 11 | wajima
# Processing Record 48 of Set 11 | uray
# Processing Record 49 of Set 11 | dutlwe
# Processing Record 50 of Set 11 | yokadouma
# Processing Record 1 of Set 12 | pechenga
# Processing Record 2 of Set 12 | sao felix do xingu
# Processing Record 3 of Set 12 | san rafael del sur
# Processing Record 4 of Set 12 | auki
# Processing Record 5 of Set 12 | berdigestyakh
# Processing Record 6 of Set 12 | nova russas
# Processing Record 7 of Set 12 | arica
# Processing Record 8 of Set 12 | copiapo
# Processing Record 9 of Set 12 | prabumulih
# Processing Record 10 of Set 12 | chazuta
# Processing Record 11 of Set 12 | kloulklubed
# Processing Record 12 of Set 12 | binucayan
# Processing Record 13 of Set 12 | bayir
# Processing Record 14 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 12 | vangaindrano
# Processing Record 16 of Set 12 | dakar
# Processing Record 17 of Set 12 | udachnyy
# Processing Record 18 of Set 12 | paamiut
# Processing Record 19 of Set 12 | itacare
# Processing Record 20 of Set 12 | marawi
# Processing Record 21 of Set 12 | alice springs
# Processing Record 22 of Set 12 | suez
# Processing Record 23 of Set 12 | scarborough
# Processing Record 24 of Set 12 | laredo
# Processing Record 25 of Set 12 | pevek
# Processing Record 26 of Set 12 | liverpool
# Processing Record 27 of Set 12 | outlook
# Processing Record 28 of Set 12 | warrnambool
# Processing Record 29 of Set 12 | hede
# Processing Record 30 of Set 12 | port lincoln
# Processing Record 31 of Set 12 | ongandjera
# Processing Record 32 of Set 12 | chardara
# Processing Record 33 of Set 12 | nobres
# Processing Record 34 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 12 | maniitsoq
# Processing Record 36 of Set 12 | cartagena
# Processing Record 37 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 12 | bulgan
# Processing Record 39 of Set 12 | brigantine
# Processing Record 40 of Set 12 | barillas
# Processing Record 41 of Set 12 | kargasok
# Processing Record 42 of Set 12 | ekhabi
# Processing Record 43 of Set 12 | opuwo
# Processing Record 44 of Set 12 | marienburg
# Processing Record 45 of Set 12 | caledon east
# Processing Record 46 of Set 12 | kajaani
# Processing Record 47 of Set 12 | talnakh
# Processing Record 48 of Set 12 | osinki
# Processing Record 49 of Set 12 | dunedin
# Processing Record 50 of Set 12 | riyadh
# Processing Record 1 of Set 13 | le port
# Processing Record 2 of Set 13 | popondetta
# Processing Record 3 of Set 13 | wakkanai
# Processing Record 4 of Set 13 | gilgit
# Processing Record 5 of Set 13 | dien bien
# City not found. Skipping...
# Processing Record 6 of Set 13 | katobu
# Processing Record 7 of Set 13 | limulunga
# Processing Record 8 of Set 13 | aksha
# Processing Record 9 of Set 13 | novobelokatay
# Processing Record 10 of Set 13 | prince rupert
# Processing Record 11 of Set 13 | cayenne
# Processing Record 12 of Set 13 | blagoyevo
# Processing Record 13 of Set 13 | la libertad
# Processing Record 14 of Set 13 | vestmannaeyjar
# Processing Record 15 of Set 13 | imbituba
# Processing Record 16 of Set 13 | ayan
# Processing Record 17 of Set 13 | manacapuru
# Processing Record 18 of Set 13 | larsnes
# Processing Record 19 of Set 13 | palauig
# Processing Record 20 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 21 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 13 | gushikawa
# Processing Record 23 of Set 13 | calama
# Processing Record 24 of Set 13 | ixtapa
# Processing Record 25 of Set 13 | manitouwadge
# Processing Record 26 of Set 13 | yebaishou
# Processing Record 27 of Set 13 | moron
# Processing Record 28 of Set 13 | balikpapan
# Processing Record 29 of Set 13 | kuala sungai baru
# Processing Record 30 of Set 13 | chimbote
# Processing Record 31 of Set 13 | cabo rojo
# Processing Record 32 of Set 13 | pangkalanbuun
# Processing Record 33 of Set 13 | kindu
# Processing Record 34 of Set 13 | ulladulla
# Processing Record 35 of Set 13 | los llanos de aridane
# Processing Record 36 of Set 13 | lagunas
# Processing Record 37 of Set 13 | inta
# Processing Record 38 of Set 13 | upata
# Processing Record 39 of Set 13 | valparaiso
# Processing Record 40 of Set 13 | sorong
# Processing Record 41 of Set 13 | udgir
# Processing Record 42 of Set 13 | lemesos
# City not found. Skipping...
# Processing Record 43 of Set 13 | sisimiut
# Processing Record 44 of Set 13 | kizema
# Processing Record 45 of Set 13 | tezu
# Processing Record 46 of Set 13 | ballina
# Processing Record 47 of Set 13 | kidal
# Processing Record 48 of Set 13 | inhambane
# Processing Record 49 of Set 13 | pattaya
# Processing Record 50 of Set 13 | yei
# Processing Record 1 of Set 14 | elko
# Processing Record 2 of Set 14 | mayo
# Processing Record 3 of Set 14 | nantucket
# Processing Record 4 of Set 14 | bubaque
# Processing Record 5 of Set 14 | hamza
# Processing Record 6 of Set 14 | kununurra
# Processing Record 7 of Set 14 | chaihe
# Processing Record 8 of Set 14 | dwarka
# Processing Record 9 of Set 14 | zonalnoye
# City not found. Skipping...
# Processing Record 10 of Set 14 | ryotsu
# Processing Record 11 of Set 14 | novoagansk
# Processing Record 12 of Set 14 | axim
# Processing Record 13 of Set 14 | kulhudhuffushi
# Processing Record 14 of Set 14 | dingle
# Processing Record 15 of Set 14 | sambava
# Processing Record 16 of Set 14 | halifax
# Processing Record 17 of Set 14 | matay
# Processing Record 18 of Set 14 | centralia
# Processing Record 19 of Set 14 | mao
# Processing Record 20 of Set 14 | buraydah
# Processing Record 21 of Set 14 | kupang
# Processing Record 22 of Set 14 | kapit
# Processing Record 23 of Set 14 | alekseyevsk
# Processing Record 24 of Set 14 | itaituba
# Processing Record 25 of Set 14 | qasigiannguit
# Processing Record 26 of Set 14 | karabulak
# Processing Record 27 of Set 14 | mount isa
# Processing Record 28 of Set 14 | esmeraldas
# Processing Record 29 of Set 14 | reconquista
# Processing Record 30 of Set 14 | goya
# Processing Record 31 of Set 14 | jaclupan
# Processing Record 32 of Set 14 | angoram
# Processing Record 33 of Set 14 | anapolis
# Processing Record 34 of Set 14 | ngunguru
# Processing Record 35 of Set 14 | quimper
# Processing Record 36 of Set 14 | san carlos de bariloche
# Processing Record 37 of Set 14 | colac
# Processing Record 38 of Set 14 | egvekinot
# Processing Record 39 of Set 14 | parabel
# Processing Record 40 of Set 14 | ishigaki
# Processing Record 41 of Set 14 | bicester
# Processing Record 42 of Set 14 | tshikapa
# Processing Record 43 of Set 14 | punta alta
# Processing Record 44 of Set 14 | lensk
# Processing Record 45 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 14 | road town
# Processing Record 47 of Set 14 | were ilu
# Processing Record 48 of Set 14 | piacabucu
# Processing Record 49 of Set 14 | algarrobo
# Processing Record 50 of Set 14 | mackay
# Processing Record 1 of Set 15 | itupiranga
# Processing Record 2 of Set 15 | stromness
# Processing Record 3 of Set 15 | ust-tsilma
# Processing Record 4 of Set 15 | galesburg
# Processing Record 5 of Set 15 | iracoubo
# Processing Record 6 of Set 15 | carangola
# Processing Record 7 of Set 15 | kenora
# Processing Record 8 of Set 15 | grand gaube
# Processing Record 9 of Set 15 | flagstaff
# Processing Record 10 of Set 15 | kalabo
# Processing Record 11 of Set 15 | vallenar
# Processing Record 12 of Set 15 | mayya
# Processing Record 13 of Set 15 | marzuq
# Processing Record 14 of Set 15 | winneba
# Processing Record 15 of Set 15 | anadyr
# Processing Record 16 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 15 | alikalia
# Processing Record 18 of Set 15 | vila
# Processing Record 19 of Set 15 | puerto carreno
# Processing Record 20 of Set 15 | touros
# Processing Record 21 of Set 15 | gazojak
# Processing Record 22 of Set 15 | barroui
# City not found. Skipping...
# Processing Record 23 of Set 15 | port hedland
# Processing Record 24 of Set 15 | maragogi
# Processing Record 25 of Set 15 | lidkoping
# Processing Record 26 of Set 15 | falmouth
# Processing Record 27 of Set 15 | wadi musa
# Processing Record 28 of Set 15 | tiznit
# Processing Record 29 of Set 15 | krasnoselkup
# Processing Record 30 of Set 15 | mora
# Processing Record 31 of Set 15 | ghanzi
# Processing Record 32 of Set 15 | corinto
# Processing Record 33 of Set 15 | voh
# Processing Record 34 of Set 15 | orange cove
# Processing Record 35 of Set 15 | faya
# Processing Record 36 of Set 15 | windsor
# Processing Record 37 of Set 15 | biryusinsk
# Processing Record 38 of Set 15 | chenghai
# Processing Record 39 of Set 15 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 40 of Set 15 | rolla
# Processing Record 41 of Set 15 | solnechnyy
# Processing Record 42 of Set 15 | lokosovo
# Processing Record 43 of Set 15 | broken hill
# Processing Record 44 of Set 15 | beja
# Processing Record 45 of Set 15 | xingyi
# Processing Record 46 of Set 15 | smithers
# Processing Record 47 of Set 15 | montmagny
# Processing Record 48 of Set 15 | soyo
# Processing Record 49 of Set 15 | havoysund
# Processing Record 50 of Set 15 | kars
# Processing Record 1 of Set 16 | kozlovka
# Processing Record 2 of Set 16 | pasighat
# Processing Record 3 of Set 16 | koslan
# Processing Record 4 of Set 16 | rayachoti
# Processing Record 5 of Set 16 | mahon
# Processing Record 6 of Set 16 | salinopolis
# Processing Record 7 of Set 16 | kisangani
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
print(city_weather)
# Out:
# {'coord': {'lon': 25.2, 'lat': 0.5167}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 72.99, 'feels_like': 73.74, 'temp_min': 72.99, 'temp_max': 72.99, 'pressure': 1012, 'humidity': 80, 'sea_level': 1012, 'grnd_level': 967}, 'visibility': 10000, 'wind': {'speed': 0.54, 'deg': 59, 'gust': 0.67}, 'clouds': {'all': 62}, 'dt': 1659473982, 'sys': {'country': 'CD', 'sunrise': 1659414076, 'sunset': 1659457774}, 'timezone': 7200, 'id': 212730, 'name': 'Kisangani', 'cod': 200}

# %%
# Add the data to a new DataFrame.
len(city_data)
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Nishihara      JP  26.1842  127.7558     81.68        89          20
# 1       Alofi      NU -19.0595 -169.9187     75.09        88          40
# 2      Dikson      RU  73.5069   80.5464     42.71        87          72
# 3  Codrington      AU -38.2667  141.9667     54.66        72          79
# 4      Olinda      BR  -8.0089  -34.8553     76.73        83          75
# 5   Busselton      AU -33.6500  115.3333     55.62        53          96
# 6     Rikitea      PF -23.1203 -134.9692     72.14        77          83
# 7   Cape Town      ZA -33.9258   18.4232     56.10        89           0
# 8      Mangai      CD  -4.0500   19.5333     79.48        50          90
# 9    Thompson      CA  55.7435  -97.8558     59.16        88         100
#
#    Wind Speed Current Description
# 0        4.61          few clouds
# 1       11.50    scattered clouds
# 2        7.83       broken clouds
# 3       20.60       broken clouds
# 4        5.75       broken clouds
# 5       29.24     overcast clouds
# 6       21.72          light rain
# 7        8.99           clear sky
# 8        3.00     overcast clouds
# 9        8.05     overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
